# %% [markdown]
# <a href="https://colab.research.google.com/github/luisosmx/python_exercises/blob/main/web_scrapper2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup


main_link = 'https://porn.jules-aubert.info/humble_bundle/all-in-one_python_by_packt/'
#main_link = 'https://porn.jules-aubert.info/humble_bundle/'
#main_link = "https://porn.jules-aubert.info/humble_bundle/"
# Making a GET request
r = requests.get(main_link)

soup = BeautifulSoup(r.text, 'html.parser')

# Find all hyperlinks present on webpage
links = soup.find_all('a')

i = 0
for link in links:
    if ('.pdf' in link.get('href', [])):
        i += 1
  
        book_name = link.get('href')
        full_link = main_link + book_name
        
        print(f"Downloading file number {i}: {full_link}")
        
        # Get response object for link
        response = requests.get(full_link)
  
        # Write content in pdf file
        pdf = open(f"{book_name}.pdf", 'wb')
        pdf.write(response.content)
        pdf.close()
        print(f"File {i}: {book_name} downloaded")

        for link in links:
            if ('.pdf' in link.get('href', [])) or ('.zip' in link.get('href', [])):
                i += 1
          
                book_name = link.get('href')
                full_link = main_link + book_name
                
                print(f"Downloading file number {i}: {full_link}")
                
                # Get response object for link
                response = requests.get(full_link)
          
                # Write content in pdf file
                if  ('.zip' in link.get('href', [])):
                  pdf = open(f"{book_name}.zip", 'wb')
                pdf = open(f"{book_name}.pdf", 'wb')
                pdf.write(response.content)
                pdf.close()
                print(f"File {i}: {book_name} downloaded")
# Out:
# ...
# File 1: 40_algorithms_every_programmer_should_know.pdf downloaded
# ...
# File 2: 40_algorithms_every_programmer_should_know.pdf downloaded
# ...
# File 3: clean_code_in_python_second_edition.pdf downloaded
# ...
# File 4: crafting_test-driven_software_with_python.pdf downloaded
# ...
# File 5: data_science_projects_with_python_second_edition.pdf downloaded
# ...
# File 6: django_3_by_example_third_edition.pdf downloaded
# ...
# File 7: expert_python_programming_fourth_edition.pdf downloaded
# ...
# File 8: hands-on_data_analysis_with_pandas_second_edition.pdf downloaded
# ...
# File 9: hands-on_financial_trading_with_python.pdf downloaded
# ...
# File 10: interpretable_machine_learning_with_python.pdf downloaded
# ...
# File 11: learn_python_programming_third_edition.pdf downloaded
# ...
# File 12: learning_opencv_4_computer_vision_with_python_3_third_edition.pdf downloaded
# ...
# File 13: machine_learning_engineering_with_python.pdf downloaded
# ...
# File 14: machine_learning_for_algorithmic_trading_second_edition.pdf downloaded
# ...

# %%
import urllib.request
zipfilename = "test.zip"
zipurl = "https://porn.jules-aubert.info/humble_bundle/all-in-one_python_by_packt/supplements/"
url = urllib.request.urlopen(zipurl)
zippedData = url.read()
  
outputFilename = "/content/zip_files" + zipfilename
print ("Saving to ",outputFilename)
output = open(outputFilename,'wb')
output.write(zippedData)
output.close()
# Out:
# Saving to  /content/zip_filestest.zip
